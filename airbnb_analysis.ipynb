# %%
# AirBnB dataset analysis
# Application for 'Koodoo'
# Applicant: Neel Patel
# Email: neel@quarithm.com

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#import airbnb data from the csv file
df = pd.read_csv('airbnb_dataset.csv')

# %%
df.head(100)
# Out:
#     property_id  host_since host_is_superhost  accommodates       State  \
# 0           109  27-06-2008                 f             6  California
# 1          2708  16-09-2008                 t             1  California
# 2          2732  17-09-2008                 f             1  California
# 3          2864  25-09-2008                 f             2  California
# 4          5728  05-03-2009                 t             2  California
# 5          5729  05-03-2009                 t             3  California
# 6          5843  05-03-2009                 t             4  California
# 7          6931  16-09-2008                 t             1  California
# 8          7874  15-06-2009                 f             2  California
# 9          7992  19-06-2009                 t             4  California
# 10         9140  29-07-2009                 f             2  California
# 11         9376  07-08-2009                 t             1  California
# 12         9545  12-08-2009                 t             1  California
# 13        10760  14-09-2009                 f             2  California
# 14        11374  29-09-2009                 f             2  California
# 15        11511  24-09-2009                 t             2  California
# 16        11877  08-08-2009                 t             1  California
# 17        12320  22-10-2009                 t             5  California
# 18        13776  12-08-2009                 t             4  California
# 19        14098  18-11-2009                 t             2  California
# 20        14107  18-11-2009                 f             8  California
# 21        14124  12-08-2009                 t             4  California
# 22        14337  21-11-2009                 f             2  California
# 23        15089  01-12-2009                 t             2  California
# 24        15333  04-12-2009                 t             6  California
# 25        18041  11-01-2010                 f             7  California
# 26        19887  29-01-2010                 t             2  California
# 27        20585  05-02-2010                 t             2  California
# 28        20786  18-11-2009                 t             2  California
# 29        22355  18-11-2009                 t             2  California
# ..          ...         ...               ...           ...         ...
# 70        53945  20-09-2010                 f             2  California
# 71        54126  05-10-2010                 f             1  California
# 72        60935  21-11-2010                 f             1  California
# 73        60940  21-11-2010                 f             1  California
# 74        61578  24-11-2010                 t             6  California
# 75        61582  24-11-2010                 t             2  California
# 76        63416  04-12-2010                 t             2  California
# 77        66796  09-07-2010                 t             2  California
# 78        67089  23-08-2010                 t             3  California
# 79        67672  03-01-2011                 t             2  California
# 80        67792  04-01-2011                 f             6  California
# 81        69838  17-01-2011                 f             4  California
# 82        71972  06-07-2010                 t             1  California
# 83        72186  10-09-2010                 f             2  California
# 84        74770  16-02-2011                 t             2  California
# 85        75212  11-01-2011                 f             2  California
# 86        75512  09-07-2010                 f             2  California
# 87        76561  22-02-2011                 t             4  California
# 88        79502  07-03-2011                 t             2  California
# 89        79832  29-07-2009                 t             2  California
# 90        80714  11-03-2011                 t             1  California
# 91        80734  11-03-2011                 t             4  California
# 92        81480  03-01-2011                 t             1  California
# 93        84636  08-08-2010                 f             2  California
# 94        84788  26-03-2011                 t             1  California
# 95        84789  28-03-2009                 f             8  California
# 96        85246  27-03-2011                 f             2  California
# 97        85973  27-03-2011                 f             2  California
# 98        86674  07-03-2011                 t             2  California
# 99        87595  02-04-2011                 t             2  California
#
#    neighbourhood_group        room_type  beds         bathrooms  bedrooms  \
# 0          Los Angeles  Entire home/apt   4.0           2 baths       2.0
# 1          Los Angeles     Private room   2.0         1.5 baths       1.0
# 2          Los Angeles     Private room   2.0    1 private bath       1.0
# 3          Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 4          Los Angeles     Private room   1.0     1 shared bath       1.0
# 5          Los Angeles     Private room   2.0     1 shared bath       1.0
# 6          Los Angeles  Entire home/apt   4.0            1 bath       2.0
# 7          Los Angeles     Private room   2.0         1.5 baths       1.0
# 8          Los Angeles     Private room   2.0     1 shared bath       1.0
# 9          Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 10         Los Angeles     Private room   2.0  1.5 shared baths       1.0
# 11         Los Angeles     Private room   2.0     1 shared bath       1.0
# 12         Los Angeles     Private room   2.0  1.5 shared baths       1.0
# 13         Los Angeles     Private room   2.0           2 baths       1.0
# 14         Los Angeles     Private room   2.0    1 private bath       1.0
# 15         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 16         Los Angeles  Entire home/apt   NaN            1 bath       NaN
# 17         Los Angeles  Entire home/apt   4.0            1 bath       2.0
# 18         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 19         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 20         Los Angeles  Entire home/apt   6.0           2 baths       3.0
# 21         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 22         Los Angeles     Private room   2.0     1 shared bath       1.0
# 23         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 24         Los Angeles     Private room   4.0     1 shared bath       2.0
# 25         Los Angeles  Entire home/apt   6.0           2 baths       3.0
# 26         Los Angeles     Private room   2.0    1 private bath       1.0
# 27         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 28         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 29         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# ..                 ...              ...   ...               ...       ...
# 70         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 71         Los Angeles     Private room   2.0         1.5 baths       1.0
# 72         Los Angeles     Private room   2.0     1 shared bath       1.0
# 73         Los Angeles     Private room   2.0     1 shared bath       1.0
# 74         Los Angeles  Entire home/apt   4.0           2 baths       2.0
# 75         Los Angeles  Entire home/apt   NaN            1 bath       NaN
# 76         Los Angeles     Private room   2.0            1 bath       1.0
# 77         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 78         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 79         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 80         Los Angeles  Entire home/apt   6.0           3 baths       3.0
# 81         Los Angeles     Private room   2.0    1 private bath       1.0
# 82         Los Angeles     Private room   2.0     1 shared bath       1.0
# 83         Los Angeles     Private room   2.0  1.5 shared baths       1.0
# 84         Los Angeles  Entire home/apt   NaN            1 bath       NaN
# 85         Los Angeles     Private room   2.0     1 shared bath       1.0
# 86         Los Angeles     Private room   2.0     1 shared bath       1.0
# 87         Los Angeles  Entire home/apt   NaN            1 bath       NaN
# 88         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 89         Los Angeles  Entire home/apt   2.0               NaN       1.0
# 90         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 91         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 92         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 93         Los Angeles     Private room   2.0    1 private bath       1.0
# 94         Los Angeles     Private room   2.0         1.5 baths       1.0
# 95         Los Angeles  Entire home/apt   8.0           2 baths       4.0
# 96         Los Angeles     Private room   2.0    1 private bath       1.0
# 97         Los Angeles  Entire home/apt   4.0            1 bath       2.0
# 98         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 99         Los Angeles  Entire home/apt   2.0            1 bath       1.0
#
#     price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0     115              30                  2               0.02
# 1      71              30                 27               0.35
# 2     155               1                 21               0.18
# 3      50              30                  0                NaN
# 4      60              30                310               2.25
# 5      70              30                230               1.69
# 6     125              30                128               1.11
# 7      73              30                 22               0.16
# 8      55               1                 12               0.53
# 9      89              30                241               2.20
# 10     80               2                393               4.20
# 11     85              30                 47               0.35
# 12     50               1                137               1.00
# 13     74              30                 45               0.34
# 14     81               1                 35               0.30
# 15    195              30                  7               0.05
# 16     70              30                 45               0.40
# 17    155              30                 10               0.37
# 18    175               2                172               1.31
# 19    289              30                 27               0.23
# 20    425              31                 30               0.24
# 21    175               2                162               1.27
# 22     95               2                  1               0.01
# 23    123               3                 70               0.52
# 24    438               2                  4               0.08
# 25    282              30                  3               0.24
# 26     75              30                253               1.94
# 27    124               3                484               3.75
# 28    199               5                 34               0.33
# 29    171              30                 44               0.35
# ..    ...             ...                ...                ...
# 70    135              31                142               1.19
# 71     42              30                  0                NaN
# 72     71              30                  0                NaN
# 73     50              30                  6               0.05
# 74    417              30                 23               0.23
# 75     78              30                  7               0.07
# 76    131              30                108               0.90
# 77    395               3                 47               0.39
# 78    135               1                557               4.65
# 79     85              31                 38               0.34
# 80    350              31                 11               0.10
# 81     89              30                597               5.08
# 82     55              30                  7               0.10
# 83     49               4                 30               0.26
# 84    109              30                121               1.02
# 85     57               1                 38               0.33
# 86     75              31                 17               0.15
# 87     79               3                617               5.26
# 88    125              31                287               2.48
# 89    110               3                483               4.12
# 90    119              30                181               1.54
# 91     90              31                110               1.25
# 92     80              31                 26               0.23
# 93     54               1                225               1.96
# 94     63              30                 70               0.83
# 95    379              30                129               1.66
# 96     95              30                 21               0.18
# 97     90              30                 25               0.22
# 98    125              30                264               2.35
# 99    105               4                439               3.79
#
#     calculated_host_listings_count  availability_365
# 0                                1               216
# 1                                2               360
# 2                                2               337
# 3                                1                 0
# 4                                5               337
# 5                                5               332
# 6                                5               154
# 7                                2               329
# 8                                3               119
# 9                                2                49
# 10                               1                 0
# 11                               2               347
# 12                               4               307
# 13                               1                87
# 14                               4               361
# 15                               2               304
# 16                               2                 6
# 17                               1                 0
# 18                               4               254
# 19                               7                 1
# 20                               1               365
# 21                               4               331
# 22                               2               365
# 23                               3               352
# 24                               2               352
# 25                               2                88
# 26                               2               365
# 27                               1                51
# 28                               7                62
# 29                               7                42
# ..                             ...               ...
# 70                               1               365
# 71                               1               362
# 72                               2               180
# 73                               2               179
# 74                               3               341
# 75                               2               311
# 76                               4               362
# 77                               1                42
# 78                               2               211
# 79                               4               266
# 80                               2               212
# 81                               1               351
# 82                               1               180
# 83                               1               306
# 84                               3               306
# 85                               1               307
# 86                               2               365
# 87                               3               132
# 88                               2               365
# 89                               1               301
# 90                               1               304
# 91                               1                 0
# 92                               4               353
# 93                               7               176
# 94                               1                 0
# 95                               5               355
# 96                               2               364
# 97                               3               134
# 98                               2               317
# 99                               2                 0
#
# [100 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158284 entries, 0 to 158283
# Data columns (total 16 columns):
# property_id                       158284 non-null int64
# host_since                        158255 non-null object
# host_is_superhost                 158255 non-null object
# accommodates                      158284 non-null int64
# State                             158284 non-null object
# neighbourhood_group               158284 non-null object
# room_type                         158284 non-null object
# beds                              141648 non-null float64
# bathrooms                         158097 non-null object
# bedrooms                          141648 non-null float64
# price                             158284 non-null int64
# minimum_nights                    158284 non-null int64
# number_of_reviews                 158284 non-null int64
# reviews_per_month                 121729 non-null float64
# calculated_host_listings_count    158284 non-null int64
# availability_365                  158284 non-null int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 19.3+ MB

# %%
df.head(200)
# Out:
#      property_id  host_since host_is_superhost  accommodates       State  \
# 0            109  27-06-2008                 f             6  California
# 1           2708  16-09-2008                 t             1  California
# 2           2732  17-09-2008                 f             1  California
# 3           2864  25-09-2008                 f             2  California
# 4           5728  05-03-2009                 t             2  California
# 5           5729  05-03-2009                 t             3  California
# 6           5843  05-03-2009                 t             4  California
# 7           6931  16-09-2008                 t             1  California
# 8           7874  15-06-2009                 f             2  California
# 9           7992  19-06-2009                 t             4  California
# 10          9140  29-07-2009                 f             2  California
# 11          9376  07-08-2009                 t             1  California
# 12          9545  12-08-2009                 t             1  California
# 13         10760  14-09-2009                 f             2  California
# 14         11374  29-09-2009                 f             2  California
# 15         11511  24-09-2009                 t             2  California
# 16         11877  08-08-2009                 t             1  California
# 17         12320  22-10-2009                 t             5  California
# 18         13776  12-08-2009                 t             4  California
# 19         14098  18-11-2009                 t             2  California
# 20         14107  18-11-2009                 f             8  California
# 21         14124  12-08-2009                 t             4  California
# 22         14337  21-11-2009                 f             2  California
# 23         15089  01-12-2009                 t             2  California
# 24         15333  04-12-2009                 t             6  California
# 25         18041  11-01-2010                 f             7  California
# 26         19887  29-01-2010                 t             2  California
# 27         20585  05-02-2010                 t             2  California
# 28         20786  18-11-2009                 t             2  California
# 29         22355  18-11-2009                 t             2  California
# ..           ...         ...               ...           ...         ...
# 170       214533  29-08-2011                 t             2  California
# 171       214870  04-09-2011                 f             2  California
# 172       215161  05-09-2011                 t             2  California
# 173       217666  10-07-2011                 f             2  California
# 174       217971  07-09-2011                 t             5  California
# 175       218672  27-03-2011                 f             5  California
# 176       221502  12-09-2011                 f             3  California
# 177       222200  07-09-2011                 t            10  California
# 178       226517  19-09-2011                 t             4  California
# 179       226609  19-09-2011                 t             2  California
# 180       226869  20-09-2011                 f             2  California
# 181       229209  09-07-2011                 t             2  California
# 182       229799  27-08-2012                 f             4  California
# 183       232085  27-09-2011                 f             2  California
# 184       234241  29-09-2011                 f             8  California
# 185       237188  08-06-2010                 t             2  California
# 186       237285  26-07-2010                 f             2  California
# 187       237985  04-10-2011                 t             2  California
# 188       237988  04-10-2011                 t             5  California
# 189       239032  27-08-2011                 f             5  California
# 190       241906  03-10-2011                 f             1  California
# 191       242108  10-10-2011                 t             6  California
# 192       244472  12-07-2011                 t             2  California
# 193       245682  17-09-2011                 f             2  California
# 194       246092  21-04-2011                 f             1  California
# 195       247898  16-10-2011                 t             2  California
# 196       253683  10-10-2011                 t             6  California
# 197       254259  25-10-2011                 t             2  California
# 198       254320  11-01-2011                 t             3  California
# 199       254844  26-10-2011                 t             4  California
#
#     neighbourhood_group        room_type  beds         bathrooms  bedrooms  \
# 0           Los Angeles  Entire home/apt   4.0           2 baths       2.0
# 1           Los Angeles     Private room   2.0         1.5 baths       1.0
# 2           Los Angeles     Private room   2.0    1 private bath       1.0
# 3           Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 4           Los Angeles     Private room   1.0     1 shared bath       1.0
# 5           Los Angeles     Private room   2.0     1 shared bath       1.0
# 6           Los Angeles  Entire home/apt   4.0            1 bath       2.0
# 7           Los Angeles     Private room   2.0         1.5 baths       1.0
# 8           Los Angeles     Private room   2.0     1 shared bath       1.0
# 9           Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 10          Los Angeles     Private room   2.0  1.5 shared baths       1.0
# 11          Los Angeles     Private room   2.0     1 shared bath       1.0
# 12          Los Angeles     Private room   2.0  1.5 shared baths       1.0
# 13          Los Angeles     Private room   2.0           2 baths       1.0
# 14          Los Angeles     Private room   2.0    1 private bath       1.0
# 15          Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 16          Los Angeles  Entire home/apt   NaN            1 bath       NaN
# 17          Los Angeles  Entire home/apt   4.0            1 bath       2.0
# 18          Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 19          Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 20          Los Angeles  Entire home/apt   6.0           2 baths       3.0
# 21          Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 22          Los Angeles     Private room   2.0     1 shared bath       1.0
# 23          Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 24          Los Angeles     Private room   4.0     1 shared bath       2.0
# 25          Los Angeles  Entire home/apt   6.0           2 baths       3.0
# 26          Los Angeles     Private room   2.0    1 private bath       1.0
# 27          Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 28          Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 29          Los Angeles  Entire home/apt   2.0            1 bath       1.0
# ..                  ...              ...   ...               ...       ...
# 170         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 171         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 172         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 173         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 174         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 175         Los Angeles  Entire home/apt   4.0           2 baths       2.0
# 176         Los Angeles     Private room   2.0         1.5 baths       1.0
# 177         Los Angeles  Entire home/apt  10.0         2.5 baths       5.0
# 178         Los Angeles     Private room   2.0    2 shared baths       1.0
# 179         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 180         Los Angeles     Private room   2.0     1 shared bath       1.0
# 181         Los Angeles     Private room   2.0            1 bath       1.0
# 182         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 183         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 184         Los Angeles     Private room   2.0         3.5 baths       1.0
# 185         Los Angeles     Private room   2.0    2 shared baths       1.0
# 186         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 187         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 188         Los Angeles  Entire home/apt   4.0         2.5 baths       2.0
# 189         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 190         Los Angeles     Private room   2.0               NaN       1.0
# 191         Los Angeles  Entire home/apt   4.0           2 baths       2.0
# 192         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 193         Los Angeles     Private room   2.0    1 private bath       1.0
# 194         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 195         Los Angeles     Private room   2.0     1 shared bath       1.0
# 196         Los Angeles  Entire home/apt   4.0           2 baths       2.0
# 197         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 198         Los Angeles  Entire home/apt   2.0            1 bath       1.0
# 199         Los Angeles  Entire home/apt   4.0         2.5 baths       2.0
#
#      price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0      115              30                  2               0.02
# 1       71              30                 27               0.35
# 2      155               1                 21               0.18
# 3       50              30                  0                NaN
# 4       60              30                310               2.25
# 5       70              30                230               1.69
# 6      125              30                128               1.11
# 7       73              30                 22               0.16
# 8       55               1                 12               0.53
# 9       89              30                241               2.20
# 10      80               2                393               4.20
# 11      85              30                 47               0.35
# 12      50               1                137               1.00
# 13      74              30                 45               0.34
# 14      81               1                 35               0.30
# 15     195              30                  7               0.05
# 16      70              30                 45               0.40
# 17     155              30                 10               0.37
# 18     175               2                172               1.31
# 19     289              30                 27               0.23
# 20     425              31                 30               0.24
# 21     175               2                162               1.27
# 22      95               2                  1               0.01
# 23     123               3                 70               0.52
# 24     438               2                  4               0.08
# 25     282              30                  3               0.24
# 26      75              30                253               1.94
# 27     124               3                484               3.75
# 28     199               5                 34               0.33
# 29     171              30                 44               0.35
# ..     ...             ...                ...                ...
# 170    106              33                  3               0.11
# 171     75              30                216               1.96
# 172    168              30                230               2.11
# 173     66              30                 74               0.68
# 174    151              30                 38               0.49
# 175    980               7                222               2.01
# 176     62              30                 30               0.28
# 177    856               3                 54               0.53
# 178     38              31                120               2.00
# 179     99               7                206               1.89
# 180     65              30                  1               0.02
# 181     92              84                124               1.13
# 182     88              30                 40               2.49
# 183     60              30                 12               0.11
# 184    125               5                  8               0.08
# 185     66               1                 41               0.45
# 186    290               1                  0                NaN
# 187    279              31                168               2.64
# 188   1299              30                102               1.58
# 189    124              20                209               2.29
# 190    200              30                  0                NaN
# 191    250               6                 11               0.10
# 192    130              31                 70               1.34
# 193     66               3                 81               0.77
# 194     75              33                 16               0.15
# 195     70              30                159               1.46
# 196    261               5                 22               0.24
# 197    155               2                429               3.92
# 198    135              30                119               1.17
# 199    813               3                157               1.55
#
#      calculated_host_listings_count  availability_365
# 0                                 1               216
# 1                                 2               360
# 2                                 2               337
# 3                                 1                 0
# 4                                 5               337
# 5                                 5               332
# 6                                 5               154
# 7                                 2               329
# 8                                 3               119
# 9                                 2                49
# 10                                1                 0
# 11                                2               347
# 12                                4               307
# 13                                1                87
# 14                                4               361
# 15                                2               304
# 16                                2                 6
# 17                                1                 0
# 18                                4               254
# 19                                7                 1
# 20                                1               365
# 21                                4               331
# 22                                2               365
# 23                                3               352
# 24                                2               352
# 25                                2                88
# 26                                2               365
# 27                                1                51
# 28                                7                62
# 29                                7                42
# ..                              ...               ...
# 170                               1               224
# 171                               2               213
# 172                               2               347
# 173                               1               250
# 174                               3               257
# 175                               5               365
# 176                               2                 0
# 177                               2               208
# 178                               3                 0
# 179                               2               320
# 180                               1                 0
# 181                               1                90
# 182                              41                 0
# 183                               1               216
# 184                               4               365
# 185                               3               359
# 186                               1               365
# 187                               4               179
# 188                               4                 0
# 189                               2               198
# 190                               1                 0
# 191                               9               179
# 192                               1                 0
# 193                               1                 0
# 194                               1               307
# 195                               4               342
# 196                               9               365
# 197                               1               301
# 198                               1               231
# 199                               1               356
#
# [200 rows x 16 columns]

# %%
df['host_since'] = pd.to_datetime(df['host_since'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158284 entries, 0 to 158283
# Data columns (total 16 columns):
# property_id                       158284 non-null int64
# host_since                        152311 non-null datetime64[ns]
# host_is_superhost                 158255 non-null object
# accommodates                      158284 non-null int64
# State                             158284 non-null object
# neighbourhood_group               158284 non-null object
# room_type                         158284 non-null object
# beds                              141648 non-null float64
# bathrooms                         158097 non-null object
# bedrooms                          141648 non-null float64
# price                             158284 non-null int64
# minimum_nights                    158284 non-null int64
# number_of_reviews                 158284 non-null int64
# reviews_per_month                 121729 non-null float64
# calculated_host_listings_count    158284 non-null int64
# availability_365                  158284 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 19.3+ MB

# %%
len(df.loc[df['host_since'].isna()])
# Out:
# 5973

# %%
df['end_date'] = pd.to_datetime('31-12-2020')

# %%
df['reviews_per_month'] = (df['end_date'].dt.year - df['host_since'].dt.year) * 12 + (df['end_date'].dt.month - df['host_since'].dt.month)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158284 entries, 0 to 158283
# Data columns (total 17 columns):
# property_id                       158284 non-null int64
# host_since                        152311 non-null datetime64[ns]
# host_is_superhost                 158255 non-null object
# accommodates                      158284 non-null int64
# State                             158284 non-null object
# neighbourhood_group               158284 non-null object
# room_type                         158284 non-null object
# beds                              141648 non-null float64
# bathrooms                         158097 non-null object
# bedrooms                          141648 non-null float64
# price                             158284 non-null int64
# minimum_nights                    158284 non-null int64
# number_of_reviews                 158284 non-null int64
# reviews_per_month                 152311 non-null float64
# calculated_host_listings_count    158284 non-null int64
# availability_365                  158284 non-null int64
# end_date                          158284 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(7), object(5)
# memory usage: 20.5+ MB

# %%
df.loc[df['reviews_per_month'].isna()]
# Out:
#         property_id host_since host_is_superhost  accommodates       State  \
# 3530        6900415        NaT               NaN             3  California
# 4937       10034835        NaT               NaN             3  California
# 13327      24304179        NaT               NaN             2  California
# 21944      38358017        NaT               NaN             2  California
# 33318      14116320        NaT               NaN            12  California
# 33319      14116330        NaT               NaN            10  California
# 33320      14116332        NaT               NaN            11  California
# 63414       8918724        NaT               NaN             4     Florida
# 63807      12536002        NaT               NaN             4     Florida
# 64394      16879934        NaT               NaN             2     Florida
# 65659      23821844        NaT               NaN             4     Florida
# 106454      2835711        NaT               NaN             3   New York
# 107621      4446862        NaT               NaN             2   New York
# 107960      4763327        NaT               NaN             4   New York
# 109079      6360224        NaT               NaN             1   New York
# 109666      6992973        NaT               NaN             4   New York
# 110099      7556587        NaT               NaN             2   New York
# 110508      8007908        NaT               NaN             5   New York
# 116016     15494796        NaT               NaN             2   New York
# 121925     23715974        NaT               NaN             4   New York
# 140564         6422        NaT                 t             2   Tennessee
# 140565        25613        NaT                 t             2   Tennessee
# 140566        65448        NaT                 f             3   Tennessee
# 140567       136015        NaT                 f             2   Tennessee
# 140568       258817        NaT                 t             2   Tennessee
# 140569       289242        NaT                 t             1   Tennessee
# 140570       319705        NaT                 t             3   Tennessee
# 140571       329997        NaT                 t             2   Tennessee
# 140572       340081        NaT                 t             3   Tennessee
# 140573       395889        NaT                 t             2   Tennessee
# ...             ...        ...               ...           ...         ...
# 146487     46257509        NaT                 f            10   Tennessee
# 146488     46260606        NaT                 t            12   Tennessee
# 146489     46261427        NaT                 f             7   Tennessee
# 146490     46264155        NaT                 f             5   Tennessee
# 146491     46275560        NaT                 f             1   Tennessee
# 146492     46277754        NaT                 f            10   Tennessee
# 146493     46278099        NaT                 t             4   Tennessee
# 146494     46278602        NaT                 t             4   Tennessee
# 146495     46278763        NaT                 t             4   Tennessee
# 146496     46278813        NaT                 t             4   Tennessee
# 146497     46279071        NaT                 f            10   Tennessee
# 146498     46294693        NaT                 f             4   Tennessee
# 146499     46294827        NaT                 f             6   Tennessee
# 146500     46300064        NaT                 f             4   Tennessee
# 146501     46301786        NaT                 f             6   Tennessee
# 146502     46309586        NaT                 f             1   Tennessee
# 146503     46315592        NaT                 f             2   Tennessee
# 146504     46331509        NaT                 f             8   Tennessee
# 146505     46332548        NaT                 f             6   Tennessee
# 146506     46332713        NaT                 t            12   Tennessee
# 146507     46332858        NaT                 t             8   Tennessee
# 146508     46333773        NaT                 t             3   Tennessee
# 154139      1614502        NaT               NaN             3  Washington
# 154167      1956274        NaT               NaN             2  Washington
# 155197     16338772        NaT               NaN             4  Washington
# 155339     18182005        NaT               NaN            10  Washington
# 155758     22292161        NaT               NaN             2  Washington
# 156742     35162444        NaT               NaN             4  Washington
# 157161     39780119        NaT               NaN             4  Washington
# 158241     45915379        NaT               NaN             2  Washington
#
#        neighbourhood_group        room_type  beds       bathrooms  bedrooms  \
# 3530           Los Angeles  Entire home/apt   2.0          1 bath       1.0
# 4937           Los Angeles     Private room   2.0          1 bath       1.0
# 13327          Los Angeles  Entire home/apt   2.0          1 bath       1.0
# 21944          Los Angeles     Private room   NaN  1 private bath       NaN
# 33318     San Diego County  Entire home/apt   8.0       4.5 baths       4.0
# 33319     San Diego County  Entire home/apt   8.0       4.5 baths       4.0
# 33320     San Diego County  Entire home/apt  10.0       4.5 baths       5.0
# 63414       Broward County  Entire home/apt   2.0          1 bath       1.0
# 63807       Broward County  Entire home/apt   2.0          1 bath       1.0
# 64394       Broward County     Private room   2.0  1 private bath       1.0
# 65659       Broward County  Entire home/apt   2.0          1 bath       1.0
# 106454           Manhattan  Entire home/apt   2.0          1 bath       1.0
# 107621            Brooklyn     Private room   2.0          1 bath       1.0
# 107960            Brooklyn  Entire home/apt   2.0          1 bath       1.0
# 109079            Brooklyn     Private room   2.0         0 baths       1.0
# 109666            Brooklyn  Entire home/apt   4.0         2 baths       2.0
# 110099           Manhattan     Private room   2.0          1 bath       1.0
# 110508           Manhattan  Entire home/apt   6.0         2 baths       3.0
# 116016           Manhattan     Private room   2.0  2 shared baths       1.0
# 121925           Manhattan  Entire home/apt   2.0          1 bath       1.0
# 140564           Nashville     Private room   4.0  1 private bath       2.0
# 140565           Nashville     Private room   2.0  1 private bath       1.0
# 140566           Nashville  Entire home/apt   2.0          1 bath       1.0
# 140567           Nashville  Entire home/apt   2.0          1 bath       1.0
# 140568           Nashville     Private room   2.0  1 private bath       1.0
# 140569           Nashville     Private room   2.0   1 shared bath       1.0
# 140570           Nashville     Private room   2.0  1 private bath       1.0
# 140571           Nashville  Entire home/apt   2.0          1 bath       1.0
# 140572           Nashville     Private room   2.0   1 shared bath       1.0
# 140573           Nashville     Private room   2.0  1 private bath       1.0
# ...                    ...              ...   ...             ...       ...
# 146487           Nashville  Entire home/apt   8.0         3 baths       4.0
# 146488           Nashville  Entire home/apt  10.0       3.5 baths       5.0
# 146489           Nashville  Entire home/apt   6.0       2.5 baths       3.0
# 146490           Nashville  Entire home/apt   6.0         2 baths       3.0
# 146491           Nashville  Entire home/apt   2.0          1 bath       1.0
# 146492           Nashville  Entire home/apt   6.0       3.5 baths       3.0
# 146493           Nashville  Entire home/apt   NaN          1 bath       NaN
# 146494           Nashville  Entire home/apt   2.0          1 bath       1.0
# 146495           Nashville  Entire home/apt   2.0          1 bath       1.0
# 146496           Nashville  Entire home/apt   NaN          1 bath       NaN
# 146497           Nashville  Entire home/apt   4.0         2 baths       2.0
# 146498           Nashville  Entire home/apt   2.0          1 bath       1.0
# 146499           Nashville  Entire home/apt   4.0         2 baths       2.0
# 146500           Nashville  Entire home/apt   2.0          1 bath       1.0
# 146501           Nashville  Entire home/apt   6.0       3.5 baths       3.0
# 146502           Nashville  Entire home/apt   NaN          1 bath       NaN
# 146503           Nashville     Private room   NaN  1 private bath       NaN
# 146504           Nashville  Entire home/apt   8.0         3 baths       4.0
# 146505           Nashville  Entire home/apt   2.0          1 bath       1.0
# 146506           Nashville  Entire home/apt   8.0       3.5 baths       4.0
# 146507           Nashville  Entire home/apt   6.0         2 baths       3.0
# 146508           Nashville  Entire home/apt   2.0          1 bath       1.0
# 154139             Seattle     Private room   2.0  1 private bath       1.0
# 154167             Seattle  Entire home/apt   2.0       1.5 baths       1.0
# 155197             Seattle  Entire home/apt   2.0          1 bath       1.0
# 155339             Seattle  Entire home/apt   8.0       2.5 baths       4.0
# 155758             Seattle  Entire home/apt   2.0          1 bath       1.0
# 156742             Seattle     Private room   4.0   1 shared bath       2.0
# 157161             Seattle  Entire home/apt   4.0         2 baths       2.0
# 158241             Seattle  Entire home/apt   2.0          1 bath       1.0
#
#         price  minimum_nights  number_of_reviews  reviews_per_month  \
# 3530       99              30                  0                NaN
# 4937       41              30                  2                NaN
# 13327     145              30                 50                NaN
# 21944     206               1                 30                NaN
# 33318    1830               1                  0                NaN
# 33319    3049               1                  0                NaN
# 33320    1708               1                  0                NaN
# 63414      94               3                114                NaN
# 63807      89               3                108                NaN
# 64394      99              30                  0                NaN
# 65659      89               3                 38                NaN
# 106454     64              30                 45                NaN
# 107621     50              30                  0                NaN
# 107960    195              30                  1                NaN
# 109079     37              30                  1                NaN
# 109666    145              30                  0                NaN
# 110099     28              30                  1                NaN
# 110508    375              30                 23                NaN
# 116016    100               1                  8                NaN
# 121925    100              30                  0                NaN
# 140564     40              30                674                NaN
# 140565     75               2                510                NaN
# 140566    165               2                 36                NaN
# 140567    103              30                 50                NaN
# 140568     29              30                 96                NaN
# 140569     26              30                 76                NaN
# 140570     31              30                 48                NaN
# 140571     76               2                985                NaN
# 140572     26              30                 77                NaN
# 140573     78               1                231                NaN
# ...       ...             ...                ...                ...
# 146487    314               2                  0                NaN
# 146488    302               2                  0                NaN
# 146489    319               2                  0                NaN
# 146490     72              30                  0                NaN
# 146491     32              30                  0                NaN
# 146492    286               1                  0                NaN
# 146493    111               2                  0                NaN
# 146494    102               2                  0                NaN
# 146495    102               2                  0                NaN
# 146496    102               2                  0                NaN
# 146497    200               2                  0                NaN
# 146498    149               2                  0                NaN
# 146499    151               2                  0                NaN
# 146500     50               1                  0                NaN
# 146501    349               2                  0                NaN
# 146502     44               1                  0                NaN
# 146503     74               1                  0                NaN
# 146504   4500              29                  0                NaN
# 146505    134               3                  0                NaN
# 146506    240               2                  0                NaN
# 146507    182               2                  0                NaN
# 146508     93              90                  0                NaN
# 154139     78               2                178                NaN
# 154167    125               3                182                NaN
# 155197     93               2                 76                NaN
# 155339    369               1                 71                NaN
# 155758     57               2                 63                NaN
# 156742     89              30                  1                NaN
# 157161    175               3                  2                NaN
# 158241     31               1                  0                NaN
#
#         calculated_host_listings_count  availability_365   end_date
# 3530                                 1                 0 2020-12-31
# 4937                                 1                 0 2020-12-31
# 13327                                1               338 2020-12-31
# 21944                                1               365 2020-12-31
# 33318                                3                 0 2020-12-31
# 33319                                3                 0 2020-12-31
# 33320                                3                53 2020-12-31
# 63414                                3               365 2020-12-31
# 63807                                3               359 2020-12-31
# 64394                                1               179 2020-12-31
# 65659                                3               359 2020-12-31
# 106454                               1               212 2020-12-31
# 107621                               1                 0 2020-12-31
# 107960                               1                 0 2020-12-31
# 109079                               1                 0 2020-12-31
# 109666                               1                 0 2020-12-31
# 110099                               1                 0 2020-12-31
# 110508                               2                 0 2020-12-31
# 116016                               2                 0 2020-12-31
# 121925                               1                 0 2020-12-31
# 140564                               1               165 2020-12-31
# 140565                               1               101 2020-12-31
# 140566                              36               344 2020-12-31
# 140567                               2               313 2020-12-31
# 140568                               6               297 2020-12-31
# 140569                               6               297 2020-12-31
# 140570                               6               282 2020-12-31
# 140571                               6               162 2020-12-31
# 140572                               6               298 2020-12-31
# 140573                               1               326 2020-12-31
# ...                                ...               ...        ...
# 146487                              17                 0 2020-12-31
# 146488                               2               144 2020-12-31
# 146489                               1                87 2020-12-31
# 146490                               1               365 2020-12-31
# 146491                               1                43 2020-12-31
# 146492                               1               151 2020-12-31
# 146493                              24               330 2020-12-31
# 146494                              24               330 2020-12-31
# 146495                              24               330 2020-12-31
# 146496                              24               330 2020-12-31
# 146497                               1                62 2020-12-31
# 146498                               2                86 2020-12-31
# 146499                               2                85 2020-12-31
# 146500                              25               217 2020-12-31
# 146501                               1                18 2020-12-31
# 146502                               8                 1 2020-12-31
# 146503                               2                84 2020-12-31
# 146504                               1               343 2020-12-31
# 146505                               1               166 2020-12-31
# 146506                               9               362 2020-12-31
# 146507                               4               355 2020-12-31
# 146508                              25               356 2020-12-31
# 154139                               1                65 2020-12-31
# 154167                               1               297 2020-12-31
# 155197                               1                57 2020-12-31
# 155339                               1               135 2020-12-31
# 155758                               1                77 2020-12-31
# 156742                               1               365 2020-12-31
# 157161                               1               180 2020-12-31
# 158241                               1               325 2020-12-31
#
# [5973 rows x 17 columns]

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    property_id host_since host_is_superhost  accommodates       State  \
# 0          109 2008-06-27                 f             6  California
# 1         2708 2008-09-16                 t             1  California
# 2         2732 2008-09-17                 f             1  California
# 3         2864 2008-09-25                 f             2  California
# 4         5728 2009-05-03                 t             2  California
#
#   neighbourhood_group        room_type  beds       bathrooms  bedrooms  price  \
# 0         Los Angeles  Entire home/apt   4.0         2 baths       2.0    115
# 1         Los Angeles     Private room   2.0       1.5 baths       1.0     71
# 2         Los Angeles     Private room   2.0  1 private bath       1.0    155
# 3         Los Angeles  Entire home/apt   2.0          1 bath       1.0     50
# 4         Los Angeles     Private room   1.0   1 shared bath       1.0     60
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0              30                  2              150.0
# 1              30                 27              147.0
# 2               1                 21              147.0
# 3              30                  0              147.0
# 4              30                310              139.0
#
#    calculated_host_listings_count  availability_365   end_date
# 0                               1               216 2020-12-31
# 1                               2               360 2020-12-31
# 2                               2               337 2020-12-31
# 3                               1                 0 2020-12-31
# 4                               5               337 2020-12-31

# %%
outlier_df = df.loc[df['price']>10000]

# %%
outlier_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 10510 to 93038
# Data columns (total 17 columns):
# property_id                       32 non-null int64
# host_since                        32 non-null datetime64[ns]
# host_is_superhost                 32 non-null int64
# accommodates                      32 non-null int64
# State                             32 non-null object
# neighbourhood_group               32 non-null object
# room_type                         32 non-null object
# beds                              32 non-null float64
# bathrooms                         32 non-null object
# bedrooms                          32 non-null float64
# price                             32 non-null int64
# minimum_nights                    32 non-null int64
# number_of_reviews                 32 non-null int64
# reviews_per_month                 32 non-null float64
# calculated_host_listings_count    32 non-null int64
# availability_365                  32 non-null int64
# end_date                          32 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(8), object(4)
# memory usage: 4.5+ KB

# %%
df.head()
# Out:
#    property_id host_since  host_is_superhost  accommodates       State  \
# 0          109 2008-06-27                  0             6  California
# 1         2708 2008-09-16                  1             1  California
# 2         2732 2008-09-17                  0             1  California
# 3         2864 2008-09-25                  0             2  California
# 4         5728 2009-05-03                  1             2  California
#
#   neighbourhood_group        room_type  beds       bathrooms  bedrooms  price  \
# 0         Los Angeles  Entire home/apt   4.0         2 baths       2.0    115
# 1         Los Angeles     Private room   2.0       1.5 baths       1.0     71
# 2         Los Angeles     Private room   2.0  1 private bath       1.0    155
# 3         Los Angeles  Entire home/apt   2.0          1 bath       1.0     50
# 4         Los Angeles     Private room   1.0   1 shared bath       1.0     60
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0              30                  2              150.0
# 1              30                 27              147.0
# 2               1                 21              147.0
# 3              30                  0              147.0
# 4              30                310              139.0
#
#    calculated_host_listings_count  availability_365   end_date
# 0                               1               216 2020-12-31
# 1                               2               360 2020-12-31
# 2                               2               337 2020-12-31
# 3                               1                 0 2020-12-31
# 4                               5               337 2020-12-31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135905 entries, 0 to 158283
# Data columns (total 17 columns):
# property_id                       135905 non-null int64
# host_since                        135905 non-null datetime64[ns]
# host_is_superhost                 135905 non-null object
# accommodates                      135905 non-null int64
# State                             135905 non-null object
# neighbourhood_group               135905 non-null object
# room_type                         135905 non-null object
# beds                              135905 non-null float64
# bathrooms                         135905 non-null object
# bedrooms                          135905 non-null float64
# price                             135905 non-null int64
# minimum_nights                    135905 non-null int64
# number_of_reviews                 135905 non-null int64
# reviews_per_month                 135905 non-null float64
# calculated_host_listings_count    135905 non-null int64
# availability_365                  135905 non-null int64
# end_date                          135905 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(7), object(5)
# memory usage: 18.7+ MB

# %%
df['host_is_superhost'] = df['host_is_superhost'].replace('t', '1')

# %%
df['host_is_superhost'] = df['host_is_superhost'].replace('f', '0')

# %%
df['host_is_superhost'] = pd.to_numeric(df['host_is_superhost'])

# %%
df.head()
# Out:
#    property_id host_since  host_is_superhost  accommodates       State  \
# 0          109 2008-06-27                  0             6  California
# 1         2708 2008-09-16                  1             1  California
# 2         2732 2008-09-17                  0             1  California
# 3         2864 2008-09-25                  0             2  California
# 4         5728 2009-05-03                  1             2  California
#
#   neighbourhood_group        room_type  beds       bathrooms  bedrooms  price  \
# 0         Los Angeles  Entire home/apt   4.0         2 baths       2.0    115
# 1         Los Angeles     Private room   2.0       1.5 baths       1.0     71
# 2         Los Angeles     Private room   2.0  1 private bath       1.0    155
# 3         Los Angeles  Entire home/apt   2.0          1 bath       1.0     50
# 4         Los Angeles     Private room   1.0   1 shared bath       1.0     60
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0              30                  2              150.0
# 1              30                 27              147.0
# 2               1                 21              147.0
# 3              30                  0              147.0
# 4              30                310              139.0
#
#    calculated_host_listings_count  availability_365   end_date
# 0                               1               216 2020-12-31
# 1                               2               360 2020-12-31
# 2                               2               337 2020-12-31
# 3                               1                 0 2020-12-31
# 4                               5               337 2020-12-31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135905 entries, 0 to 158283
# Data columns (total 17 columns):
# property_id                       135905 non-null int64
# host_since                        135905 non-null datetime64[ns]
# host_is_superhost                 135905 non-null int64
# accommodates                      135905 non-null int64
# State                             135905 non-null object
# neighbourhood_group               135905 non-null object
# room_type                         135905 non-null object
# beds                              135905 non-null float64
# bathrooms                         135905 non-null object
# bedrooms                          135905 non-null float64
# price                             135905 non-null int64
# minimum_nights                    135905 non-null int64
# number_of_reviews                 135905 non-null int64
# reviews_per_month                 135905 non-null float64
# calculated_host_listings_count    135905 non-null int64
# availability_365                  135905 non-null int64
# end_date                          135905 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(8), object(4)
# memory usage: 18.7+ MB

# %%
df.describe()
# Out:
#         property_id  host_is_superhost   accommodates           beds  \
# count  1.359050e+05      135905.000000  135905.000000  135905.000000
# mean   2.662325e+07           0.323160       3.905883       3.226879
# std    1.398386e+07           0.467685       2.635867       2.059289
# min    1.090000e+02           0.000000       1.000000       1.000000
# 25%    1.541094e+07           0.000000       2.000000       2.000000
# 50%    2.785082e+07           0.000000       4.000000       2.000000
# 75%    3.971493e+07           1.000000       5.000000       4.000000
# max    4.694186e+07           1.000000      16.000000     100.000000
#
#             bedrooms          price  minimum_nights  number_of_reviews  \
# count  135905.000000  135905.000000    1.359050e+05      135905.000000
# mean        1.613502     212.081763    7.501759e+02         110.347809
# std         1.029639     526.034592    2.712578e+05         276.222618
# min         1.000000      10.000000    1.000000e+00           0.000000
# 25%         1.000000      75.000000    2.000000e+00           1.000000
# 50%         1.000000     125.000000    3.000000e+00          11.000000
# 75%         2.000000     208.000000    3.000000e+01          60.000000
# max        50.000000   25000.000000    1.000000e+08        1825.000000
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# count      135905.000000                   135905.000000     135905.000000
# mean           59.272337                       18.383165        177.353762
# std            30.055875                       48.635197        139.312016
# min             0.000000                        1.000000          0.000000
# 25%            37.000000                        1.000000         34.000000
# 50%            59.000000                        2.000000        173.000000
# 75%            80.000000                        8.000000        326.000000
# max           154.000000                      386.000000        365.000000

# %%
df.corr()
# Out:
#                                 property_id  host_is_superhost  accommodates  \
# property_id                        1.000000          -0.075648      0.077881
# host_is_superhost                 -0.075648           1.000000      0.061590
# accommodates                       0.077881           0.061590      1.000000
# beds                               0.053812           0.035318      0.810380
# bedrooms                           0.053774           0.035307      0.810396
# price                              0.018157          -0.013278      0.293178
# minimum_nights                    -0.002193          -0.001884     -0.000944
# number_of_reviews                 -0.092155           0.075417      0.122901
# reviews_per_month                 -0.524955           0.059664     -0.048713
# calculated_host_listings_count     0.154465          -0.026524      0.072756
# availability_365                   0.061166           0.057741      0.112714
#
#                                     beds  bedrooms     price  minimum_nights  \
# property_id                     0.053812  0.053774  0.018157       -0.002193
# host_is_superhost               0.035318  0.035307 -0.013278       -0.001884
# accommodates                    0.810380  0.810396  0.293178       -0.000944
# beds                            1.000000  0.999968  0.334517       -0.001621
# bedrooms                        0.999968  1.000000  0.334522       -0.001621
# price                           0.334517  0.334522  1.000000       -0.000745
# minimum_nights                 -0.001621 -0.001621 -0.000745        1.000000
# number_of_reviews               0.060107  0.060096  0.061854       -0.001016
# reviews_per_month              -0.019417 -0.019407 -0.011971        0.008194
# calculated_host_listings_count  0.016589  0.016576  0.050056       -0.000968
# availability_365                0.081729  0.081740  0.034633       -0.003453
#
#                                 number_of_reviews  reviews_per_month  \
# property_id                             -0.092155          -0.524955
# host_is_superhost                        0.075417           0.059664
# accommodates                             0.122901          -0.048713
# beds                                     0.060107          -0.019417
# bedrooms                                 0.060096          -0.019407
# price                                    0.061854          -0.011971
# minimum_nights                          -0.001016           0.008194
# number_of_reviews                        1.000000           0.026052
# reviews_per_month                        0.026052           1.000000
# calculated_host_listings_count           0.133598          -0.083168
# availability_365                         0.114636          -0.072047
#
#                                 calculated_host_listings_count  \
# property_id                                           0.154465
# host_is_superhost                                    -0.026524
# accommodates                                          0.072756
# beds                                                  0.016589
# bedrooms                                              0.016576
# price                                                 0.050056
# minimum_nights                                       -0.000968
# number_of_reviews                                     0.133598
# reviews_per_month                                    -0.083168
# calculated_host_listings_count                        1.000000
# availability_365                                      0.167422
#
#                                 availability_365
# property_id                             0.061166
# host_is_superhost                       0.057741
# accommodates                            0.112714
# beds                                    0.081729
# bedrooms                                0.081740
# price                                   0.034633
# minimum_nights                         -0.003453
# number_of_reviews                       0.114636
# reviews_per_month                      -0.072047
# calculated_host_listings_count          0.167422
# availability_365                        1.000000

# %%
cor = df.corr()
correlated_ordered = cor.unstack().sort_values(kind="quicksort")
print(correlated_ordered)
# Out:
# reviews_per_month               property_id                      -0.524955
# property_id                     reviews_per_month                -0.524955
#                                 number_of_reviews                -0.092155
# number_of_reviews               property_id                      -0.092155
# reviews_per_month               calculated_host_listings_count   -0.083168
# calculated_host_listings_count  reviews_per_month                -0.083168
# property_id                     host_is_superhost                -0.075648
# host_is_superhost               property_id                      -0.075648
# reviews_per_month               availability_365                 -0.072047
# availability_365                reviews_per_month                -0.072047
# reviews_per_month               accommodates                     -0.048713
# accommodates                    reviews_per_month                -0.048713
# calculated_host_listings_count  host_is_superhost                -0.026524
# host_is_superhost               calculated_host_listings_count   -0.026524
# reviews_per_month               beds                             -0.019417
# beds                            reviews_per_month                -0.019417
# reviews_per_month               bedrooms                         -0.019407
# bedrooms                        reviews_per_month                -0.019407
# price                           host_is_superhost                -0.013278
# host_is_superhost               price                            -0.013278
# price                           reviews_per_month                -0.011971
# reviews_per_month               price                            -0.011971
# availability_365                minimum_nights                   -0.003453
# minimum_nights                  availability_365                 -0.003453
# property_id                     minimum_nights                   -0.002193
# minimum_nights                  property_id                      -0.002193
# host_is_superhost               minimum_nights                   -0.001884
# minimum_nights                  host_is_superhost                -0.001884
# bedrooms                        minimum_nights                   -0.001621
# minimum_nights                  bedrooms                         -0.001621
#                                                                     ...
# number_of_reviews               accommodates                      0.122901
#                                 calculated_host_listings_count    0.133598
# calculated_host_listings_count  number_of_reviews                 0.133598
# property_id                     calculated_host_listings_count    0.154465
# calculated_host_listings_count  property_id                       0.154465
#                                 availability_365                  0.167422
# availability_365                calculated_host_listings_count    0.167422
# accommodates                    price                             0.293178
# price                           accommodates                      0.293178
# beds                            price                             0.334517
# price                           beds                              0.334517
# bedrooms                        price                             0.334522
# price                           bedrooms                          0.334522
# beds                            accommodates                      0.810380
# accommodates                    beds                              0.810380
#                                 bedrooms                          0.810396
# bedrooms                        accommodates                      0.810396
# beds                            bedrooms                          0.999968
# bedrooms                        beds                              0.999968
# property_id                     property_id                       1.000000
# price                           price                             1.000000
# reviews_per_month               reviews_per_month                 1.000000
# number_of_reviews               number_of_reviews                 1.000000
# minimum_nights                  minimum_nights                    1.000000
# bedrooms                        bedrooms                          1.000000
# beds                            beds                              1.000000
# accommodates                    accommodates                      1.000000
# host_is_superhost               host_is_superhost                 1.000000
# calculated_host_listings_count  calculated_host_listings_count    1.000000
# availability_365                availability_365                  1.000000
# Length: 121, dtype: float64

# %% [markdown]
# # How many features are represented in the dataset?
# There are 15 features (property_id is not included in this as its a unique identifier)
#
# Types of variables:
# - "host_since":
# - "host_is_superhost":
# - "room_type":
# - "bedrooms":
# - "price":

# %%
sns.displot(df['bedrooms'])

# %%
sns.displot(df['host_is_superhost'])

# %%
sns.catplot(x="room type", kind="count", palette="ch:.25", data=df["room_type"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-34e3e2533ff7> in <module>()
#       1
# ----> 2 sns.catplot(x="room type", kind="count", palette="ch:.25", data=df["room_type"])
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3787     p = _CategoricalPlotter()
#    3788     p.require_numeric = plotter_class.require_numeric
# -> 3789     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3790     if (
#    3791         order is not None
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'room type'

# %%
#sns.displot(df['bedrooms'])
set(xlim=(0,15),ylim=(0,100))
sns.displot(data=df, x="bedrooms", ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-c0b12a542722> in <module>()
#       1 #sns.displot(df['bedrooms'])
# ----> 2 set(xlim=(0,15),ylim=(0,100))
#       3 sns.displot(data=df, x="bedrooms", ax=ax)
#       4 plt.show()
#
# TypeError: set() does not take keyword arguments

# %%
#sns.displot(df['price'])
df['price'].hist(bins=100)

# %% [markdown]
# # What are the two most correlated variables?
# - "Beds" & "Bedrooms" are the two most correlated variables - 0.999971

# %% [markdown]
# # What are the two least correlated variables?
# - "calculated_host_listings_count" &  "reviews_per_month" are the two least correlated variables - -0.134020

# %% [markdown]
# # Correlation matrix plot

# %%
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# # How does the price distribution vary by state? And by room type?
# -

# %%
print('hello')
# Out:
# hello
