# %%
# AirBnB dataset analysis
# Application for 'Koodoo'
# Applicant: Neel Patel
# Email: neel@quarithm.com

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %%
#import airbnb data from the csv file
df = pd.read_csv('airbnb_dataset.csv')

# %%
df.head()
# Out:
#    property_id  host_since host_is_superhost  accommodates       State  \
# 0          109  27-06-2008                 f             6  California
# 1         2708  16-09-2008                 t             1  California
# 2         2732  17-09-2008                 f             1  California
# 3         2864  25-09-2008                 f             2  California
# 4         5728  05-03-2009                 t             2  California
#
#   neighbourhood_group        room_type  beds       bathrooms  bedrooms  price  \
# 0         Los Angeles  Entire home/apt   4.0         2 baths       2.0    115
# 1         Los Angeles     Private room   2.0       1.5 baths       1.0     71
# 2         Los Angeles     Private room   2.0  1 private bath       1.0    155
# 3         Los Angeles  Entire home/apt   2.0          1 bath       1.0     50
# 4         Los Angeles     Private room   1.0   1 shared bath       1.0     60
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0              30                  2               0.02
# 1              30                 27               0.35
# 2               1                 21               0.18
# 3              30                  0                NaN
# 4              30                310               2.25
#
#    calculated_host_listings_count  availability_365
# 0                               1               216
# 1                               2               360
# 2                               2               337
# 3                               1                 0
# 4                               5               337

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158284 entries, 0 to 158283
# Data columns (total 16 columns):
# property_id                       158284 non-null int64
# host_since                        158255 non-null object
# host_is_superhost                 158255 non-null object
# accommodates                      158284 non-null int64
# State                             158284 non-null object
# neighbourhood_group               158284 non-null object
# room_type                         158284 non-null object
# beds                              141648 non-null float64
# bathrooms                         158097 non-null object
# bedrooms                          141648 non-null float64
# price                             158284 non-null int64
# minimum_nights                    158284 non-null int64
# number_of_reviews                 158284 non-null int64
# reviews_per_month                 121729 non-null float64
# calculated_host_listings_count    158284 non-null int64
# availability_365                  158284 non-null int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 19.3+ MB

# %%
df['host_since'] = pd.to_datetime(df['host_since'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158284 entries, 0 to 158283
# Data columns (total 16 columns):
# property_id                       158284 non-null int64
# host_since                        152311 non-null datetime64[ns]
# host_is_superhost                 158255 non-null object
# accommodates                      158284 non-null int64
# State                             158284 non-null object
# neighbourhood_group               158284 non-null object
# room_type                         158284 non-null object
# beds                              141648 non-null float64
# bathrooms                         158097 non-null object
# bedrooms                          141648 non-null float64
# price                             158284 non-null int64
# minimum_nights                    158284 non-null int64
# number_of_reviews                 158284 non-null int64
# reviews_per_month                 121729 non-null float64
# calculated_host_listings_count    158284 non-null int64
# availability_365                  158284 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 19.3+ MB

# %%
df['host_since'].max()
# Out:
# Timestamp('2020-12-11 00:00:00')

# %%
df_bedrooms_na = df.loc[df['bedrooms'].isna()]
df_bedrooms_na
# Out:
#         property_id  host_since host_is_superhost  accommodates       State  \
# 16            11877  08-08-2009                 t             1  California
# 30            23363  11-03-2010                 f             2  California
# 62            49731  07-09-2010                 t             1  California
# 65            51498  16-09-2010                 f             2  California
# 75            61582  24-11-2010                 t             2  California
# 84            74770  16-02-2011                 t             2  California
# 87            76561  22-02-2011                 t             4  California
# 109          101702  24-04-2011                 t             2  California
# 111          106052  02-05-2011                 t             2  California
# 120          127766  20-04-2011                 t             2  California
# 126          135608  24-10-2017                 f             1  California
# 136          160142  25-06-2011                 t             2  California
# 202          256092  25-10-2011                 t             2  California
# 208          260684  25-10-2011                 t             2  California
# 213          265119  02-11-2011                 f             2  California
# 229          286771  25-10-2011                 t             2  California
# 242          299876  29-12-2011                 t             2  California
# 294          371574  06-03-2012                 t             2  California
# 308          400940  24-03-2012                 f             3  California
# 343          454265  22-11-2011                 f             2  California
# 363          499612  25-05-2012                 f             3  California
# 372          520181  16-02-2012                 t             3  California
# 421          580131  06-07-2012                 f             2  California
# 481          669808  27-08-2012                 f             3  California
# 482          669825  27-08-2012                 f             3  California
# 541          739143  14-10-2012                 t             1  California
# 549          746115  18-10-2012                 t             2  California
# 583          797694  24-10-2017                 f             1  California
# 584          798535  16-04-2012                 t             2  California
# 590          808891  14-08-2011                 f             2  California
# ...             ...         ...               ...           ...         ...
# 158084     45596596  28-07-2020                 t             1  Washington
# 158088     45607173  28-07-2020                 t             1  Washington
# 158096     45635497  30-01-2015                 f             2  Washington
# 158099     45641533  28-10-2017                 f             2  Washington
# 158128     45700361  28-07-2020                 t             1  Washington
# 158130     45700505  28-07-2020                 t             1  Washington
# 158131     45700506  28-07-2020                 t             1  Washington
# 158147     45737222  30-08-2013                 f             2  Washington
# 158153     45740036  28-07-2020                 t             1  Washington
# 158155     45742504  28-07-2020                 t             1  Washington
# 158158     45749222  30-08-2013                 f             2  Washington
# 158162     45752217  01-02-2014                 f             2  Washington
# 158163     45752949  24-05-2014                 t             2  Washington
# 158170     45768467  17-11-2018                 f             4  Washington
# 158172     45768556  17-11-2018                 f             4  Washington
# 158173     45769114  28-07-2020                 t             1  Washington
# 158189     45787902  28-07-2020                 t             1  Washington
# 158203     45837480  16-12-2016                 f             2  Washington
# 158216     45870397  16-12-2016                 f             2  Washington
# 158226     45878530  28-07-2020                 t             1  Washington
# 158227     45880576  28-07-2020                 t             1  Washington
# 158236     45904038  16-12-2016                 f             2  Washington
# 158243     45924051  28-07-2020                 t             1  Washington
# 158247     45937532  04-12-2018                 f             2  Washington
# 158254     45960931  31-12-2015                 f             4  Washington
# 158257     45976831  28-07-2020                 t             1  Washington
# 158258     45979220  28-07-2020                 t             1  Washington
# 158265     45993973  28-07-2020                 t             1  Washington
# 158267     46008177  28-07-2020                 t             1  Washington
# 158269     46013454  23-10-2020                 f             2  Washington
#
#        neighbourhood_group        room_type  beds        bathrooms  bedrooms  \
# 16             Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 30             Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 62             Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 65             Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 75             Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 84             Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 87             Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 109            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 111            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 120            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 126            Los Angeles     Private room   NaN  11 shared baths       NaN
# 136            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 202            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 208            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 213            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 229            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 242            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 294            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 308            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 343            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 363            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 372            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 421            Los Angeles     Private room   NaN   1 private bath       NaN
# 481            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 482            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 541            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 549            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 583            Los Angeles     Private room   NaN  11 shared baths       NaN
# 584            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# 590            Los Angeles  Entire home/apt   NaN           1 bath       NaN
# ...                    ...              ...   ...              ...       ...
# 158084             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158088             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158096             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158099             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158128             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158130             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158131             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158147             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158153             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158155             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158158             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158162             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158163             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158170             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158172             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158173             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158189             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158203             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158216             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158226             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158227             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158236             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158243             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158247             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158254             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158257             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158258             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158265             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158267             Seattle  Entire home/apt   NaN           1 bath       NaN
# 158269             Seattle  Entire home/apt   NaN           1 bath       NaN
#
#         price  minimum_nights  number_of_reviews  reviews_per_month  \
# 16         70              30                 45               0.40
# 30        111               3                172               1.53
# 62         60               7                 13               0.20
# 65        109              30                307               2.50
# 75         78              30                  7               0.07
# 84        109              30                121               1.02
# 87         79               3                617               5.26
# 109       100              30                217               1.88
# 111        66               5                369               3.20
# 120        90              28                 10               0.11
# 126        42               2                 90               0.91
# 136        90               6                100               1.62
# 202        67              31                 16               0.15
# 208        68              31                 18               0.17
# 213        89               2                140               2.37
# 229        67              31                 20               0.20
# 242       106              31                 22               0.21
# 294        69              31                 14               0.15
# 308       141               1                505               4.84
# 343       125               3                 57               0.56
# 363       166              30                 12               0.12
# 372       176               1                 56               0.55
# 421       121               2                437               4.33
# 481        75              30                 47               0.49
# 482        79              30                 37               0.37
# 541       100              30                 95               1.07
# 549       227              30                106               1.26
# 583        43               2                 38               0.44
# 584        83               3                116               2.41
# 590        80              30                152               1.58
# ...       ...             ...                ...                ...
# 158084    118              30                  0                NaN
# 158088    111              30                  0                NaN
# 158096     39               1                  3               3.00
# 158099     59               3                  1               1.00
# 158128    107              30                  0                NaN
# 158130    107              30                  0                NaN
# 158131    108              30                  0                NaN
# 158147    105               2                  0                NaN
# 158153     91              30                  0                NaN
# 158155    142              30                  0                NaN
# 158158    105               2                  0                NaN
# 158162     88               1                  0                NaN
# 158163     80              20                  0                NaN
# 158170     93               2                  0                NaN
# 158172     80               4                  0                NaN
# 158173    135              30                  0                NaN
# 158189     99              30                  0                NaN
# 158203    119              30                  0                NaN
# 158216    111              30                  0                NaN
# 158226    131              30                  0                NaN
# 158227    134              30                  0                NaN
# 158236    119              30                  0                NaN
# 158243     92              30                  0                NaN
# 158247     63               3                  0                NaN
# 158254     90              30                  0                NaN
# 158257    143              30                  0                NaN
# 158258    117              30                  0                NaN
# 158265    100              90                  0                NaN
# 158267    175              30                  0                NaN
# 158269     88               1                  0                NaN
#
#         calculated_host_listings_count  availability_365
# 16                                   2                 6
# 30                                   1                 9
# 62                                   2               316
# 65                                   1               365
# 75                                   2               311
# 84                                   3               306
# 87                                   3               132
# 109                                  2               323
# 111                                  1               321
# 120                                  4               337
# 126                                 20                 0
# 136                                  1                 0
# 202                                  3               216
# 208                                  3               186
# 213                                  1               248
# 229                                  3               275
# 242                                  2               217
# 294                                  1                 0
# 308                                  2               270
# 343                                  1               300
# 363                                  1               337
# 372                                 10               350
# 421                                  2               171
# 481                                 41               346
# 482                                 41               338
# 541                                  3                37
# 549                                  1               272
# 583                                 20                 1
# 584                                  1               323
# 590                                  9               292
# ...                                ...               ...
# 158084                             350               360
# 158088                             350               360
# 158096                              19                 4
# 158099                               1                15
# 158128                             350               360
# 158130                             350               360
# 158131                             350               354
# 158147                             123               335
# 158153                             350               348
# 158155                             350               353
# 158158                             123               333
# 158162                               9                80
# 158163                               2                 0
# 158170                               5                32
# 158172                               5                51
# 158173                             350               359
# 158189                             350               360
# 158203                              44               365
# 158216                              44               365
# 158226                             350               342
# 158227                             350               341
# 158236                              44               365
# 158243                             350                 0
# 158247                               1               176
# 158254                               1                52
# 158257                             350               353
# 158258                             350               336
# 158265                             350               360
# 158267                             350               333
# 158269                               1               172
#
# [16636 rows x 16 columns]

# %%
from pprint import pprint
pprint(df_bedrooms_na['bathrooms'].unique())
# Out:
# array(['1 bath', '11 shared baths', '1 private bath', '0 shared baths',
#        nan, '1.5 baths', '0 baths', '1 shared bath', 'Half-bath',
#        '2 baths', 'Shared half-bath', '4 baths', 'Private half-bath',
#        '2 shared baths', '4.5 baths', '1.5 shared baths',
#        '3 shared baths', '3 baths', '6 baths', '2.5 shared baths',
#        '2.5 baths', '5 baths', '3.5 baths', '6 shared baths',
#        '3.5 shared baths', '4 shared baths'], dtype=object)

# %%
df_cleaned1 =- df.drop([''])

# %%
df.loc[df['price'] < 1600]['price'].hist(bins=100);

# %%
df.describe()
# Out:
#         property_id   accommodates           beds       bedrooms  \
# count  1.582840e+05  158284.000000  141648.000000  141648.000000
# mean   2.687205e+07       3.857415       3.276298       1.638209
# std    1.391804e+07       2.644342       2.122781       1.061383
# min    1.090000e+02       0.000000       1.000000       1.000000
# 25%    1.580311e+07       2.000000       2.000000       1.000000
# 50%    2.820504e+07       3.000000       2.000000       1.000000
# 75%    3.987180e+07       5.000000       4.000000       2.000000
# max    4.694186e+07      16.000000     100.000000      50.000000
#
#                price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  158284.000000    1.582840e+05      158284.000000      121729.000000
# mean      204.351697    6.458261e+02         112.351362           1.364372
# std       500.177613    2.513515e+05         278.058914           1.638410
# min         0.000000    1.000000e+00           0.000000           0.010000
# 25%        75.000000    2.000000e+00           1.000000           0.220000
# 50%       120.000000    3.000000e+00          12.000000           0.750000
# 75%       200.000000    3.000000e+01          62.000000           1.980000
# max     25000.000000    1.000000e+08        1825.000000          37.280000
#
#        calculated_host_listings_count  availability_365
# count                   158284.000000     158284.000000
# mean                        18.867188        177.763956
# std                         48.882172        139.180331
# min                          1.000000          0.000000
# 25%                          1.000000         36.000000
# 50%                          2.000000        173.000000
# 75%                          8.000000        326.000000
# max                        386.000000        365.000000

# %%
df.corr()
# Out:
#                                 property_id  accommodates      beds  bedrooms  \
# property_id                        1.000000      0.077763  0.059695  0.059660
# accommodates                       0.077763      1.000000  0.812358  0.812372
# beds                               0.059695      0.812358  1.000000  0.999971
# bedrooms                           0.059660      0.812372  0.999971  1.000000
# price                              0.015669      0.289674  0.336037  0.336042
# minimum_nights                    -0.002087     -0.000828 -0.001603 -0.001603
# number_of_reviews                 -0.097888      0.091903  0.049523  0.049513
# reviews_per_month                  0.094961      0.045563 -0.012537 -0.012523
# calculated_host_listings_count     0.159032      0.057699  0.019423  0.019411
# availability_365                   0.065855      0.113756  0.088135  0.088146
#
#                                    price  minimum_nights  number_of_reviews  \
# property_id                     0.015669       -0.002087          -0.097888
# accommodates                    0.289674       -0.000828           0.091903
# beds                            0.336037       -0.001603           0.049523
# bedrooms                        0.336042       -0.001603           0.049513
# price                           1.000000       -0.000687           0.052470
# minimum_nights                 -0.000687        1.000000          -0.000955
# number_of_reviews               0.052470       -0.000955           1.000000
# reviews_per_month              -0.072695       -0.002122           0.092644
# calculated_host_listings_count  0.043989       -0.000917           0.119996
# availability_365                0.034748       -0.003210           0.111214
#
#                                 reviews_per_month  \
# property_id                              0.094961
# accommodates                             0.045563
# beds                                    -0.012537
# bedrooms                                -0.012523
# price                                   -0.072695
# minimum_nights                          -0.002122
# number_of_reviews                        0.092644
# reviews_per_month                        1.000000
# calculated_host_listings_count          -0.134020
# availability_365                         0.038693
#
#                                 calculated_host_listings_count  \
# property_id                                           0.159032
# accommodates                                          0.057699
# beds                                                  0.019423
# bedrooms                                              0.019411
# price                                                 0.043989
# minimum_nights                                       -0.000917
# number_of_reviews                                     0.119996
# reviews_per_month                                    -0.134020
# calculated_host_listings_count                        1.000000
# availability_365                                      0.168939
#
#                                 availability_365
# property_id                             0.065855
# accommodates                            0.113756
# beds                                    0.088135
# bedrooms                                0.088146
# price                                   0.034748
# minimum_nights                         -0.003210
# number_of_reviews                       0.111214
# reviews_per_month                       0.038693
# calculated_host_listings_count          0.168939
# availability_365                        1.000000

# %%
df.corr().min()
# Out:
# property_id                      -0.097888
# accommodates                     -0.000828
# beds                             -0.012537
# bedrooms                         -0.012523
# price                            -0.072695
# minimum_nights                   -0.003210
# number_of_reviews                -0.097888
# reviews_per_month                -0.134020
# calculated_host_listings_count   -0.134020
# availability_365                 -0.003210
# dtype: float64

# %%
cor = df.corr()
correlated_ordered = cor.unstack().sort_values(kind="quicksort")
print(correlated_ordered)
# Out:
# calculated_host_listings_count  reviews_per_month                -0.134020
# reviews_per_month               calculated_host_listings_count   -0.134020
# property_id                     number_of_reviews                -0.097888
# number_of_reviews               property_id                      -0.097888
# reviews_per_month               price                            -0.072695
# price                           reviews_per_month                -0.072695
# beds                            reviews_per_month                -0.012537
# reviews_per_month               beds                             -0.012537
# bedrooms                        reviews_per_month                -0.012523
# reviews_per_month               bedrooms                         -0.012523
# availability_365                minimum_nights                   -0.003210
# minimum_nights                  availability_365                 -0.003210
#                                 reviews_per_month                -0.002122
# reviews_per_month               minimum_nights                   -0.002122
# property_id                     minimum_nights                   -0.002087
# minimum_nights                  property_id                      -0.002087
# bedrooms                        minimum_nights                   -0.001603
# minimum_nights                  bedrooms                         -0.001603
#                                 beds                             -0.001603
# beds                            minimum_nights                   -0.001603
# minimum_nights                  number_of_reviews                -0.000955
# number_of_reviews               minimum_nights                   -0.000955
# minimum_nights                  calculated_host_listings_count   -0.000917
# calculated_host_listings_count  minimum_nights                   -0.000917
# minimum_nights                  accommodates                     -0.000828
# accommodates                    minimum_nights                   -0.000828
# price                           minimum_nights                   -0.000687
# minimum_nights                  price                            -0.000687
# property_id                     price                             0.015669
# price                           property_id                       0.015669
#                                                                     ...
# availability_365                accommodates                      0.113756
# accommodates                    availability_365                  0.113756
# calculated_host_listings_count  number_of_reviews                 0.119996
# number_of_reviews               calculated_host_listings_count    0.119996
# calculated_host_listings_count  property_id                       0.159032
# property_id                     calculated_host_listings_count    0.159032
# availability_365                calculated_host_listings_count    0.168939
# calculated_host_listings_count  availability_365                  0.168939
# accommodates                    price                             0.289674
# price                           accommodates                      0.289674
#                                 beds                              0.336037
# beds                            price                             0.336037
# bedrooms                        price                             0.336042
# price                           bedrooms                          0.336042
# beds                            accommodates                      0.812358
# accommodates                    beds                              0.812358
# bedrooms                        accommodates                      0.812372
# accommodates                    bedrooms                          0.812372
# beds                            bedrooms                          0.999971
# bedrooms                        beds                              0.999971
# property_id                     property_id                       1.000000
# reviews_per_month               reviews_per_month                 1.000000
# number_of_reviews               number_of_reviews                 1.000000
# minimum_nights                  minimum_nights                    1.000000
# price                           price                             1.000000
# bedrooms                        bedrooms                          1.000000
# beds                            beds                              1.000000
# accommodates                    accommodates                      1.000000
# calculated_host_listings_count  calculated_host_listings_count    1.000000
# availability_365                availability_365                  1.000000
# Length: 100, dtype: float64

# %% [markdown]
# # How many features are represented in the dataset?
# There are 15 features (property_id is not included in this as its a unique identifier)
#
# Types of variables:
# - "host_since":
# - "host_is_superhost":
# - "room_type":
# - "bedrooms":
# - "price":

# %%
sns.distplot(df['bedrooms'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-04ce28449316> in <module>()
# ----> 1 sns.distplot(df['bedrooms'])
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     210     if hist:
#     211         if bins is None:
# --> 212             bins = min(_freedman_diaconis_bins(a), 50)
#     213         hist_kws.setdefault("alpha", 0.4)
#     214         hist_kws.setdefault("normed", norm_hist)
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      34         return int(np.sqrt(a.size))
#      35     else:
# ---> 36         return int(np.ceil((a.max() - a.min()) / h))
#      37
#      38
#
# ValueError: cannot convert float NaN to integer

# %%
sns.distplot(df,x='host_is_superhost')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-22a01cde62a5> in <module>()
# ----> 1 sns.distplot(df,x='host_is_superhost')
#
# TypeError: distplot() got an unexpected keyword argument 'x'

# %%
sns.displot(df,x='room_type')

# %%
sns.displot(df,x='bedrooms')

# %%
sns.displot(df,x='price')

# %% [markdown]
# # What are the two most correlated variables?
# - "Beds" & "Bedrooms" are the two most correlated variables - 0.999971

# %% [markdown]
# # What are the two least correlated variables?
# - "calculated_host_listings_count" &  "reviews_per_month" are the two least correlated variables - -0.134020

# %% [markdown]
# # Correlation matrix plot

# %%
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# # How does the price distribution vary by state? And by room type?
# -

# %%
print('hello')
# Out:
# hello
